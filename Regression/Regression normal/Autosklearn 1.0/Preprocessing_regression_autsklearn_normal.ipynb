# %%
import sklearn as sk
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("combined.csv")

# %%
df.head()
# Out:
#         Type    Price Bedrooms Bathrooms   Area Furnished Level     Compound  \
# 0  Apartment  1980000        3         3  148.0        No     3        Nyoum
# 1  Apartment  4724000        2         2  120.0   Unknown     3  Sun Capital
# 2  Apartment   355000        3         2  109.0   Unknown     2      Unknown
# 3  Apartment  3000000        2         2  128.0        No     2  Bloomfields
# 4  Apartment  2900000        2         2  120.0   Unknown     1  Sun Capital
#
#         Payment_Option  Delivery_Date  Delivery_Term                    City  \
# 0  Cash or Installment           2024  Semi Finished              Asyut City
# 1  Cash or Installment           2025       Finished          6th of October
# 2      Unknown Payment           soon        Unknown         Zahraa Al Maadi
# 3  Cash or Installment           soon   Not Finished  New Cairo - El Tagamoa
# 4          Installment  Ready to move        Unknown          6th of October
#
#         Ad_Date Scraping_Date
# ...

# %%
df = df.drop(columns=['Scraping_Date', 'Ad_Date'])

# %%
df.head()
# Out:
#         Type    Price Bedrooms Bathrooms   Area Furnished Level     Compound  \
# 0  Apartment  1980000        3         3  148.0        No     3        Nyoum
# 1  Apartment  4724000        2         2  120.0   Unknown     3  Sun Capital
# 2  Apartment   355000        3         2  109.0   Unknown     2      Unknown
# 3  Apartment  3000000        2         2  128.0        No     2  Bloomfields
# 4  Apartment  2900000        2         2  120.0   Unknown     1  Sun Capital
#
#         Payment_Option  Delivery_Date  Delivery_Term                    City
# 0  Cash or Installment           2024  Semi Finished              Asyut City
# 1  Cash or Installment           2025       Finished          6th of October
# 2      Unknown Payment           soon        Unknown         Zahraa Al Maadi
# 3  Cash or Installment           soon   Not Finished  New Cairo - El Tagamoa
# 4          Installment  Ready to move        Unknown          6th of October

# %%
from os import PRIO_PROCESS
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np


# All Unknown values as NaN
df.replace('Unknown', np.nan, inplace=True)
df_cleaned = df.dropna(subset=['Price']) #drop rows with NaN in target

df['Price'] = df['Price'].astype(float)
df['Bathrooms'] = df['Bathrooms'].astype(float)
df['Bedrooms'] = df['Bedrooms'].astype(float)
df['Area'] = df['Area'].astype(float)

# all NaN with mode
df.fillna(df.mode().iloc[0], inplace=True)



df = pd.DataFrame(df)

df.head()
# Out:
#         Type      Price  Bedrooms  Bathrooms   Area Furnished Level  \
# 0  Apartment  1980000.0       3.0        3.0  148.0        No     3
# 1  Apartment  4724000.0       2.0        2.0  120.0        No     3
# 2  Apartment   355000.0       3.0        2.0  109.0        No     2
# 3  Apartment  3000000.0       2.0        2.0  128.0        No     2
# 4  Apartment  2900000.0       2.0        2.0  120.0        No     1
#
#       Compound       Payment_Option  Delivery_Date  Delivery_Term  \
# 0        Nyoum  Cash or Installment           2024  Semi Finished
# 1  Sun Capital  Cash or Installment           2025       Finished
# 2     Madinaty      Unknown Payment           soon       Finished
# 3  Bloomfields  Cash or Installment           soon   Not Finished
# 4  Sun Capital          Installment  Ready to move       Finished
#
#                      City
# 0              Asyut City
# 1          6th of October
# 2         Zahraa Al Maadi
# 3  New Cairo - El Tagamoa
# ...

# %%
df.shape
# Out:
# (15311, 12)

# %%
#download
from google.colab import files
df.to_csv('combined_regression_normal.csv', index=False)
files.download('combined_regression_normal.csv')
